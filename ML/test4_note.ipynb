# %%
# %matplotlib inline

# %%
import test4

# %%
a, b, c, d = test4.load_classification_data()

# %%
test4.test_KNeighborsClassifier_k_w(a, b, c, d)

# %%
from imp import reload

# %%
reload(test4)
# Out:
# <module 'test4' from '/home/enningxie/PycharmProjects/ML/test4.py'>

# %%
test4.test_KNeighborsClassifier_k_p(a, b, c, d)

# %%
reload(test4)
# Out:
# <module 'test4' from '/home/enningxie/PycharmProjects/ML/test4.py'>

# %%
a, b, c, d = test4.load_regression_data(1000)

# %%
test4.test_KNeighborsRegressor(a, b, c, d)
# Out:
# Training score: 0.972196569147
# Test score: 0.957388854832

# %%
reload(test4)
# Out:
# <module 'test4' from '/home/enningxie/PycharmProjects/ML/test4.py'>

# %%
test4.test_KNeighborsRegressor_k_w(a, b, c, d)

# %%
reload(test4)
# Out:
# <module 'test4' from '/home/enningxie/PycharmProjects/ML/test4.py'>

# %%
test4.test_KNeighborsRegressor_k_p(a, b, c, d)
